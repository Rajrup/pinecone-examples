# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/pinecone-io/examples/blob/master/learn/search/question-answering/question-answering.ipynb) [![Open nbviewer](https://raw.githubusercontent.com/pinecone-io/examples/master/assets/nbviewer-shield.svg)](https://nbviewer.org/github/pinecone-io/examples/blob/master/learn/search/question-answering/question-answering.ipynb)
#
# # Question Answering with Similarity Search

# %% [markdown]
# This notebook demonstrates how Pinecone's similarity search as a service helps you build a question answering application. We will index a set of questions and retrieve the most similar stored questions for a new (unseen) question. That way, we can link a new question to answers we might already have.
#
# You can build a questions answering application with Pinecone in three steps:
# - Represent questions as vector embeddings so that semantically similar questions are in close proximity within the same vector space.
# - Index vectors using Pinecone.
# - Given a new question, query the index to fetch similar questions. This can allow us to store answers associated with these questions
#
# In this notebook we will be dealing with indexing a set of quetions and retrieving similar questions for a new and unseen question.

# %% [markdown]
# ## Dependencies

# %%
# !pip install -qU pinecone-client
# !pip install -qU matplotlib ipywidgets
# !pip install -qU sentence-transformers

# %%
import pandas as pd
import numpy as np

# %matplotlib inline

# %% [markdown]
# # PART 1: Indexing Questions to Pinecone
#
# We will start by indexing a set of questions to Pinecone. We will use the `sentence-transformers` library to convert the questions into vector embeddings. We will then index these embeddings using Pinecone.

# %% [markdown]
# ## Pinecone Installation and Setup

# %%
from pinecone import Pinecone, ServerlessSpec
import os

# load Pinecone API key
api_key = os.getenv("PINECONE_API_KEY") or "d11bd0fa-9723-487b-ae13-7f51b5b22772"
print(api_key)

pinecone = Pinecone(api_key=api_key)
spec=ServerlessSpec(
        cloud="aws",
        region="us-west-2"
    )
# Out:
# d11bd0fa-9723-487b-ae13-7f51b5b22772

# %% [markdown]
# ## Create a New Pinecone Index

# %%
# pick a name for the new index
index_name = "question-answering"

# %% [markdown]
# **Create index**

# %%
# check whether an index with the same name already exists

if index_name in pinecone.list_indexes().names():
    pinecone.delete_index(index_name)
pinecone.create_index(name=index_name, dimension=300, spec=spec)

# %% [markdown]
# **Connect to the index**
#
# The index object, a class instance of pinecone.Index , will be reused for optimal performance.

# %%
host = pinecone.describe_index(name=index_name).host
index = pinecone.Index(host=host)

# %% [markdown]
# ## Uploading Questions

# %% [markdown]
# The dataset used in this notebook is the [Quora Question Pairs Dataset](https://www.kaggle.com/c/quora-question-pairs).

# %% [markdown]
# Let's download the dataset and load the data.

# %%
# download dataset from the url
import requests

DATA_DIR = "tmp"
DATA_FILE = f"{DATA_DIR}/quora_duplicate_questions.tsv"
DATA_URL = "https://qim.fs.quoracdn.net/quora_duplicate_questions.tsv"


def download_data():
    os.makedirs(DATA_DIR, exist_ok=True)

    if not os.path.exists(DATA_FILE):
        r = requests.get(DATA_URL)  # create HTTP response object
        with open(DATA_FILE, "wb") as f:
            f.write(r.content)


download_data()

# %%
pd.set_option("display.max_colwidth", 500)

df = pd.read_csv(
    f"{DATA_FILE}", sep="\t", usecols=["qid1", "question1"], index_col=False
)
df = df.sample(frac=1).reset_index(drop=True)
df.drop_duplicates(inplace=True)
df['qid1'] = df['qid1'].apply(str)
df['question1'] = df['question1'].apply(str)
print(df.head())
# Out:
#      qid1  \
# 0  401595
# 1   13728
# 2   67930
# 3  223923
# 4  316481
#
#                                                                   question1
# 0  Which day of the week has the hardest crossword puzzle in the newspaper?
# 1                                                         Who is Redd Foxx?
# 2   What is the difference between a turbo charger and a turbo intercooler?
# 3                            How do I get my contacts back after rebooting?
# 4                              What are some cultural faux pas at LinkedIn?

# %% [markdown]
# ### Define the model: Generate embeddings for questions

# %% [markdown]
# We will use the [Averarage Word Embeddings Model](https://nlp.stanford.edu/projects/glove/) for this example. This model has a high computation speed but relatively low quality of embeddings. You can look into other sentence embeddings models such as the [Sentence Embeddings Models trained on Paraphrases](https://huggingface.co/sentence-transformers/paraphrase-distilroberta-base-v1) for improving quality of embeddings.

# %%
import torch
from sentence_transformers import SentenceTransformer

# set device to GPU if available
device = 'cuda' if torch.cuda.is_available() else 'cpu'
# load the model from huggingface model hub
model = SentenceTransformer("average_word_embeddings_glove.6B.300d", device=device)

# %% [markdown]
# ### Creating Vector Embeddings

# %%
# create embedding for each question
question_vectors = model.encode(list(df.question1), show_progress_bar=True).tolist()
# Out:
# Batches:   0%|          | 0/9083 [00:00<?, ?it/s]

# %%
# add question embeddings to dataframe
df["question_vector"] = question_vectors

# %%
#find row indices with all zeros in df.question_vector
zero_rows = df[df.question_vector.apply(lambda x: np.sum(x)==0.0)].index
df_zero= df.loc[zero_rows].question_vector
df_non_zero=df.drop(zero_rows)

# %% [markdown]
# ### Index the Vectors

# %%
import itertools

def chunks(iterable, batch_size=1000):
    it = iter(iterable)
    chunk = tuple(itertools.islice(it, batch_size))
    while chunk:
        yield chunk
        chunk = tuple(itertools.islice(it, batch_size))

# %%
batch_size = 1000
total_size = len(df_non_zero)
print("Total size:", total_size)
print("Num of batches:", total_size/batch_size)

done = 0
for i, batch in enumerate(chunks(zip(df_non_zero.qid1, df_non_zero.question_vector), batch_size=batch_size)):
    done += len(batch)
    print("Batch: {}, Done: {}".format(i, done))
    index.upsert(vectors=batch)
# Out:
# Total size: 289952
# Num of batches: 289.952
# Batch: 0, Done: 1000
# Batch: 1, Done: 2000
# Batch: 2, Done: 3000
# Batch: 3, Done: 4000
# Batch: 4, Done: 5000
# Batch: 5, Done: 6000
# Batch: 6, Done: 7000
# Batch: 7, Done: 8000
# Batch: 8, Done: 9000
# Batch: 9, Done: 10000
# Batch: 10, Done: 11000
# Batch: 11, Done: 12000
# Batch: 12, Done: 13000
# Batch: 13, Done: 14000
# Batch: 14, Done: 15000
# Batch: 15, Done: 16000
# Batch: 16, Done: 17000
# Batch: 17, Done: 18000
# Batch: 18, Done: 19000
# Batch: 19, Done: 20000
# Batch: 20, Done: 21000
# Batch: 21, Done: 22000
# Batch: 22, Done: 23000
# Batch: 23, Done: 24000
# Batch: 24, Done: 25000
# Batch: 25, Done: 26000
# Batch: 26, Done: 27000
# Batch: 27, Done: 28000
# Batch: 28, Done: 29000
# Batch: 29, Done: 30000
# Batch: 30, Done: 31000
# Batch: 31, Done: 32000
# Batch: 32, Done: 33000
# Batch: 33, Done: 34000
# Batch: 34, Done: 35000
# Batch: 35, Done: 36000
# Batch: 36, Done: 37000
# Batch: 37, Done: 38000
# Batch: 38, Done: 39000
# Batch: 39, Done: 40000
# Batch: 40, Done: 41000
# Batch: 41, Done: 42000
# Batch: 42, Done: 43000
# Batch: 43, Done: 44000
# Batch: 44, Done: 45000
# Batch: 45, Done: 46000
# Batch: 46, Done: 47000
# Batch: 47, Done: 48000
# Batch: 48, Done: 49000
# Batch: 49, Done: 50000
# Batch: 50, Done: 51000
# Batch: 51, Done: 52000
# Batch: 52, Done: 53000
# Batch: 53, Done: 54000
# Batch: 54, Done: 55000
# Batch: 55, Done: 56000
# Batch: 56, Done: 57000
# Batch: 57, Done: 58000
# Batch: 58, Done: 59000
# Batch: 59, Done: 60000
# Batch: 60, Done: 61000
# Batch: 61, Done: 62000
# Batch: 62, Done: 63000
# Batch: 63, Done: 64000
# Batch: 64, Done: 65000
# Batch: 65, Done: 66000
# Batch: 66, Done: 67000
# Batch: 67, Done: 68000
# Batch: 68, Done: 69000
# Batch: 69, Done: 70000
# Batch: 70, Done: 71000
# Batch: 71, Done: 72000
# Batch: 72, Done: 73000
# Batch: 73, Done: 74000
# Batch: 74, Done: 75000
# Batch: 75, Done: 76000
# Batch: 76, Done: 77000
# Batch: 77, Done: 78000
# Batch: 78, Done: 79000
# Batch: 79, Done: 80000
# Batch: 80, Done: 81000
# Batch: 81, Done: 82000
# Batch: 82, Done: 83000
# Batch: 83, Done: 84000
# Batch: 84, Done: 85000
# Batch: 85, Done: 86000
# Batch: 86, Done: 87000
# Batch: 87, Done: 88000
# Batch: 88, Done: 89000
# Batch: 89, Done: 90000
# Batch: 90, Done: 91000
# Batch: 91, Done: 92000
# Batch: 92, Done: 93000
# Batch: 93, Done: 94000
# Batch: 94, Done: 95000
# Batch: 95, Done: 96000
# Batch: 96, Done: 97000
# Batch: 97, Done: 98000
# Batch: 98, Done: 99000
# Batch: 99, Done: 100000
# Batch: 100, Done: 101000
# Batch: 101, Done: 102000
# Batch: 102, Done: 103000
# Batch: 103, Done: 104000
# Batch: 104, Done: 105000
# Batch: 105, Done: 106000
# Batch: 106, Done: 107000
# Batch: 107, Done: 108000
# Batch: 108, Done: 109000
# Batch: 109, Done: 110000
# Batch: 110, Done: 111000
# Batch: 111, Done: 112000
# Batch: 112, Done: 113000
# Batch: 113, Done: 114000
# Batch: 114, Done: 115000
# Batch: 115, Done: 116000
# Batch: 116, Done: 117000
# Batch: 117, Done: 118000
# Batch: 118, Done: 119000
# Batch: 119, Done: 120000
# Batch: 120, Done: 121000
# Batch: 121, Done: 122000
# Batch: 122, Done: 123000
# Batch: 123, Done: 124000
# Batch: 124, Done: 125000
# Batch: 125, Done: 126000
# Batch: 126, Done: 127000
# Batch: 127, Done: 128000
# Batch: 128, Done: 129000
# Batch: 129, Done: 130000
# Batch: 130, Done: 131000
# Batch: 131, Done: 132000
# Batch: 132, Done: 133000
# Batch: 133, Done: 134000
# Batch: 134, Done: 135000
# Batch: 135, Done: 136000
# Batch: 136, Done: 137000
# Batch: 137, Done: 138000
# Batch: 138, Done: 139000
# Batch: 139, Done: 140000
# Batch: 140, Done: 141000
# Batch: 141, Done: 142000
# Batch: 142, Done: 143000
# Batch: 143, Done: 144000
# Batch: 144, Done: 145000
# Batch: 145, Done: 146000
# Batch: 146, Done: 147000
# Batch: 147, Done: 148000
# Batch: 148, Done: 149000
# Batch: 149, Done: 150000
# Batch: 150, Done: 151000
# Batch: 151, Done: 152000
# Batch: 152, Done: 153000
# Batch: 153, Done: 154000
# Batch: 154, Done: 155000
# Batch: 155, Done: 156000
# Batch: 156, Done: 157000
# Batch: 157, Done: 158000
# Batch: 158, Done: 159000
# Batch: 159, Done: 160000
# Batch: 160, Done: 161000
# Batch: 161, Done: 162000
# Batch: 162, Done: 163000
# Batch: 163, Done: 164000
# Batch: 164, Done: 165000
# Batch: 165, Done: 166000
# Batch: 166, Done: 167000
# Batch: 167, Done: 168000
# Batch: 168, Done: 169000
# Batch: 169, Done: 170000
# Batch: 170, Done: 171000
# Batch: 171, Done: 172000
# Batch: 172, Done: 173000
# Batch: 173, Done: 174000
# Batch: 174, Done: 175000
# Batch: 175, Done: 176000
# Batch: 176, Done: 177000
# Batch: 177, Done: 178000
# Batch: 178, Done: 179000
# Batch: 179, Done: 180000
# Batch: 180, Done: 181000
# Batch: 181, Done: 182000
# Batch: 182, Done: 183000
# Batch: 183, Done: 184000
# Batch: 184, Done: 185000
# Batch: 185, Done: 186000
# Batch: 186, Done: 187000
# Batch: 187, Done: 188000
# Batch: 188, Done: 189000
# Batch: 189, Done: 190000
# Batch: 190, Done: 191000
# Batch: 191, Done: 192000
# Batch: 192, Done: 193000
# Batch: 193, Done: 194000
# Batch: 194, Done: 195000
# Batch: 195, Done: 196000
# Batch: 196, Done: 197000
# Batch: 197, Done: 198000
# Batch: 198, Done: 199000
# Batch: 199, Done: 200000
# Batch: 200, Done: 201000
# Batch: 201, Done: 202000
# Batch: 202, Done: 203000
# Batch: 203, Done: 204000
# Batch: 204, Done: 205000
# Batch: 205, Done: 206000
# Batch: 206, Done: 207000
# Batch: 207, Done: 208000
# Batch: 208, Done: 209000
# Batch: 209, Done: 210000
# Batch: 210, Done: 211000
# Batch: 211, Done: 212000
# Batch: 212, Done: 213000
# Batch: 213, Done: 214000
# Batch: 214, Done: 215000
# Batch: 215, Done: 216000
# Batch: 216, Done: 217000
# Batch: 217, Done: 218000
# Batch: 218, Done: 219000
# Batch: 219, Done: 220000
# Batch: 220, Done: 221000
# Batch: 221, Done: 222000
# Batch: 222, Done: 223000
# Batch: 223, Done: 224000
# Batch: 224, Done: 225000
# Batch: 225, Done: 226000
# Batch: 226, Done: 227000
# Batch: 227, Done: 228000
# Batch: 228, Done: 229000
# Batch: 229, Done: 230000
# Batch: 230, Done: 231000
# Batch: 231, Done: 232000
# Batch: 232, Done: 233000
# Batch: 233, Done: 234000
# Batch: 234, Done: 235000
# Batch: 235, Done: 236000
# Batch: 236, Done: 237000
# Batch: 237, Done: 238000
# Batch: 238, Done: 239000
# Batch: 239, Done: 240000
# Batch: 240, Done: 241000
# Batch: 241, Done: 242000
# Batch: 242, Done: 243000
# Batch: 243, Done: 244000
# Batch: 244, Done: 245000
# Batch: 245, Done: 246000
# Batch: 246, Done: 247000
# Batch: 247, Done: 248000
# Batch: 248, Done: 249000
# Batch: 249, Done: 250000
# Batch: 250, Done: 251000
# Batch: 251, Done: 252000
# Batch: 252, Done: 253000
# Batch: 253, Done: 254000
# Batch: 254, Done: 255000
# Batch: 255, Done: 256000
# Batch: 256, Done: 257000
# Batch: 257, Done: 258000
# Batch: 258, Done: 259000
# Batch: 259, Done: 260000
# Batch: 260, Done: 261000
# Batch: 261, Done: 262000
# Batch: 262, Done: 263000
# Batch: 263, Done: 264000
# Batch: 264, Done: 265000
# Batch: 265, Done: 266000
# Batch: 266, Done: 267000
# Batch: 267, Done: 268000
# Batch: 268, Done: 269000
# Batch: 269, Done: 270000
# Batch: 270, Done: 271000
# Batch: 271, Done: 272000
# Batch: 272, Done: 273000
# Batch: 273, Done: 274000
# Batch: 274, Done: 275000
# Batch: 275, Done: 276000
# Batch: 276, Done: 277000
# Batch: 277, Done: 278000
# Batch: 278, Done: 279000
# Batch: 279, Done: 280000
# Batch: 280, Done: 281000
# Batch: 281, Done: 282000
# Batch: 282, Done: 283000
# Batch: 283, Done: 284000
# Batch: 284, Done: 285000
# Batch: 285, Done: 286000
# Batch: 286, Done: 287000
# Batch: 287, Done: 288000
# Batch: 288, Done: 289000
# Batch: 289, Done: 289952

# %% [markdown]
# # PART 2: Retrival
#
# Once indexing is done, we can retrieve similar questions for a new question.

# %%
import pandas as pd
import numpy as np

# %matplotlib inline

# %%
from pinecone import Pinecone, ServerlessSpec
import os

# load Pinecone API key
api_key = os.getenv("PINECONE_API_KEY") or "d11bd0fa-9723-487b-ae13-7f51b5b22772"
print(api_key)

pinecone = Pinecone(api_key=api_key)
spec=ServerlessSpec(
        cloud="aws",
        region="us-west-2"
    )
# Out:
# d11bd0fa-9723-487b-ae13-7f51b5b22772

# %% [markdown]
# **Connect to the index**
#
# The index object, a class instance of pinecone.Index , will be reused for optimal performance.

# %%
# pick the name for index
index_name = "question-answering"

host = pinecone.describe_index(name=index_name).host
index = pinecone.Index(host=host)

# %% [markdown]
# ### Define the model: Generate embeddings for questions

# %% [markdown]
# We will use the [Averarage Word Embeddings Model](https://nlp.stanford.edu/projects/glove/) for this example. This model has a high computation speed but relatively low quality of embeddings. You can look into other sentence embeddings models such as the [Sentence Embeddings Models trained on Paraphrases](https://huggingface.co/sentence-transformers/paraphrase-distilroberta-base-v1) for improving quality of embeddings.

# %%
import torch
from sentence_transformers import SentenceTransformer

# set device to GPU if available
device = 'cuda' if torch.cuda.is_available() else 'cpu'
# load the model from huggingface model hub
model = SentenceTransformer("average_word_embeddings_glove.6B.300d", device=device)

# %% [markdown]
# ## Load Dataset

# %%
# download dataset from the url
import requests

DATA_DIR = "tmp"
DATA_FILE = f"{DATA_DIR}/quora_duplicate_questions.tsv"
DATA_URL = "https://qim.fs.quoracdn.net/quora_duplicate_questions.tsv"


def download_data():
    os.makedirs(DATA_DIR, exist_ok=True)

    if not os.path.exists(DATA_FILE):
        r = requests.get(DATA_URL)  # create HTTP response object
        with open(DATA_FILE, "wb") as f:
            f.write(r.content)


download_data()

# %%
pd.set_option("display.max_colwidth", 500)

df = pd.read_csv(
    f"{DATA_FILE}", sep="\t", usecols=["qid1", "question1"], index_col=False
)
df = df.sample(frac=1).reset_index(drop=True)
df.drop_duplicates(inplace=True)
df['qid1'] = df['qid1'].apply(str)
df['question1'] = df['question1'].apply(str)
print(df.head())
# Out:
#      qid1  \
# 0   94563
# 1  119479
# 2  479223
# 3  286210
# 4  408408
#
#                                                                                            question1
# 0  Did you enjoy your school life? Did you ever wonder you would have been better off home schooled?
# 1                      What is the best thing to do to start being involved in open source projects?
# 2                                 Which is more important for overall well-being, sleep or exercise?
# 3                     What are some examples of romantic Korean dramas that are popular in the West?
# 4                                                                        Did Quora get hacked today?

# %% [markdown]
# ## Search

# %% [markdown]
# Once you have indexed the vectors it is very straightforward to query the index. These are the steps you need to follow:
# - Select a set of questions you want to query with
# - Use the Average Embedding Model to transform questions into embeddings.
# - Send each question vector to the Pinecone index and retrieve most similar indexed questions

# %%
# define questions to query the vector index
query_questions = [
    "What is best way to make money online?",
    "How can i build an e-commerce website?"
]

# extract embeddings for the questions
query_vectors = model.encode(query_questions).tolist()

# query pinecone
query_results = [index.query(vector=xq, top_k=5) for xq in query_vectors]

# show the results
for question, res in zip(query_questions, query_results):
    print("\n\n\n Original question : " + str(question))
    print("\n Most similar questions based on pinecone vector search: \n")

    ids = [match.id for match in res.matches]
    scores = [match.score for match in res.matches]
    df_result = pd.DataFrame(
        {
            "id": ids,
            "question": [
                df[df.qid1 == _id].question1.values[0] for _id in ids
            ],
            "score": scores,
        }
    )
    print(df_result)
# Out:
#  Original question : What is best way to make money online?
#
#  Most similar questions based on pinecone vector search:
#
#        id                                             question     score
# 0      57               What is best way to make money online?  0.999613
# 1  297469           What is the best way to make money online?  0.999613
# 2   55585        What is the best way for making money online?  0.989048
# 3  157045  What is the best way to make money on the internet?  0.980163
# 4   28280         What are the best ways to make money online?  0.979453
#
#
#
#  Original question : How can i build an e-commerce website?
#
#  Most similar questions based on pinecone vector search:
#
#        id                                                   question     score
# 0  119383                   How can I develop an e-commerce website?  0.924485
# 1    1713                 How would I develop an e-commerce website?  0.924485
# 2    1714                     How do I create an e-commerce website?  0.919350
# 3   79063             How do I build and host an e-commerce website?  0.918179
# 4  245780  What is the best platform to build an e-commerce website?  0.893813
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Delete the Index

# %% [markdown]
# Delete the index once you are sure that you do not want to use it anymore. Once it is deleted, you cannot reuse it.

# %%
# pinecone.delete_index(index_name)
